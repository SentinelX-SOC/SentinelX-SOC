# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.data_loader import inspect_gzip_file

AUTH_PATH = PROJECT_ROOT / "data" / "raw" / "auth.txt.gz"
REDTEAM_PATH = PROJECT_ROOT / "data" / "raw" / "redteam.txt.gz"
inspect_gzip_file(AUTH_PATH, sample_lines=15)
inspect_gzip_file(REDTEAM_PATH, sample_lines=15)
# Out:
# --- d:\Hackathons\SOC Analyst\autonomous-threat-defense\data\raw\auth.txt.gz ---
# 01: 1,ANONYMOUS LOGON@C586,ANONYMOUS LOGON@C586,C1250,C586,NTLM,Network,LogOn,Success
# 02: 1,ANONYMOUS LOGON@C586,ANONYMOUS LOGON@C586,C586,C586,?,Network,LogOff,Success
# 03: 1,C101$@DOM1,C101$@DOM1,C988,C988,?,Network,LogOff,Success
# 04: 1,C1020$@DOM1,SYSTEM@C1020,C1020,C1020,Negotiate,Service,LogOn,Success
# 05: 1,C1021$@DOM1,C1021$@DOM1,C1021,C625,Kerberos,Network,LogOn,Success
# 06: 1,C1035$@DOM1,C1035$@DOM1,C1035,C586,Kerberos,Network,LogOn,Success
# 07: 1,C1035$@DOM1,C1035$@DOM1,C586,C586,?,Network,LogOff,Success
# 08: 1,C1069$@DOM1,SYSTEM@C1069,C1069,C1069,Negotiate,Service,LogOn,Success
# 09: 1,C1085$@DOM1,C1085$@DOM1,C1085,C612,Kerberos,Network,LogOn,Success
# 10: 1,C1085$@DOM1,C1085$@DOM1,C612,C612,?,Network,LogOff,Success
# 11: 1,C1151$@DOM1,SYSTEM@C1151,C1151,C1151,Negotiate,Service,LogOn,Success
# 12: 1,C1154$@DOM1,SYSTEM@C1154,C1154,C1154,Negotiate,Service,LogOn,Success
# ...
